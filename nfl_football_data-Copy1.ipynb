# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

df = pd.read_csv("nfl_data.csv")
df.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0      9/2/1966             1966             1             False
# 1      9/3/1966             1966             1             False
# 2      9/4/1966             1966             1             False
# 3      9/9/1966             1966             2             False
# 4     9/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# ...

# %%
#Remove columns that aren't needed
df_football = df.drop([ 'schedule_week', 'schedule_playoff', 'team_away', 'team_favorite_id', 'spread_favorite', 'over_under_line', 'stadium', 'stadium_neutral', 'weather_temperature', 'weather_wind_mph', 'weather_humidity', 'weather_detail'], axis=1)

# %%
#Add column for wins and losses. True = Win
df_football['win_or_loss'] = df_football['score_home'] > df_football['score_away']
df_football
# Out:
#       schedule_date  schedule_season             team_home  score_home  \
# 0          9/2/1966             1966        Miami Dolphins        14.0
# 1          9/3/1966             1966        Houston Oilers        45.0
# 2          9/4/1966             1966    San Diego Chargers        27.0
# 3          9/9/1966             1966        Miami Dolphins        14.0
# 4         9/10/1966             1966     Green Bay Packers        24.0
# ...             ...              ...                   ...         ...
# 12929      1/3/2021             2020  New England Patriots         NaN
# 12930      1/3/2021             2020       New York Giants         NaN
# 12931      1/3/2021             2020   Philadelphia Eagles         NaN
# 12932      1/3/2021             2020   San Francisco 49ers         NaN
# 12933      1/3/2021             2020  Tampa Bay Buccaneers         NaN
#
#        score_away  win_or_loss
# 0            23.0        False
# 1             7.0         True
# ...

# %%
#Convert boolean to integer
df_football['win_or_loss'] = df.apply(lambda row: row['score_home'] > row['score_away'], axis=1).astype(int)
df_football
# Out:
#       schedule_date  schedule_season             team_home  score_home  \
# 0          9/2/1966             1966        Miami Dolphins        14.0
# 1          9/3/1966             1966        Houston Oilers        45.0
# 2          9/4/1966             1966    San Diego Chargers        27.0
# 3          9/9/1966             1966        Miami Dolphins        14.0
# 4         9/10/1966             1966     Green Bay Packers        24.0
# ...             ...              ...                   ...         ...
# 12929      1/3/2021             2020  New England Patriots         NaN
# 12930      1/3/2021             2020       New York Giants         NaN
# 12931      1/3/2021             2020   Philadelphia Eagles         NaN
# 12932      1/3/2021             2020   San Francisco 49ers         NaN
# 12933      1/3/2021             2020  Tampa Bay Buccaneers         NaN
#
#        score_away  win_or_loss
# 0            23.0            0
# 1             7.0            1
# ...

# %%
#Convert integers to Win or Loss
df_football.replace({1: 'Win', 0: 'Loss'}, inplace=True)
df_football
# Out:
#       schedule_date  schedule_season             team_home score_home  \
# 0          9/2/1966             1966        Miami Dolphins         14
# 1          9/3/1966             1966        Houston Oilers         45
# 2          9/4/1966             1966    San Diego Chargers         27
# 3          9/9/1966             1966        Miami Dolphins         14
# 4         9/10/1966             1966     Green Bay Packers         24
# ...             ...              ...                   ...        ...
# 12929      1/3/2021             2020  New England Patriots        NaN
# 12930      1/3/2021             2020       New York Giants        NaN
# 12931      1/3/2021             2020   Philadelphia Eagles        NaN
# 12932      1/3/2021             2020   San Francisco 49ers        NaN
# 12933      1/3/2021             2020  Tampa Bay Buccaneers        NaN
#
#       score_away win_or_loss
# 0             23        Loss
# 1              7         Win
# 2              7         Win
# ...

# %%
grouped_by_team_df = pd.DataFrame(df_football.groupby(["schedule_season"]))
grouped_by_year_df
# Out:
#        0                                                  1
# 0   1966      schedule_date  schedule_season            ...
# 1   1967      schedule_date  schedule_season           t...
# 2   1968      schedule_date  schedule_season           t...
# 3   1969      schedule_date  schedule_season           t...
# 4   1970      schedule_date  schedule_season            ...
# 5   1971       schedule_date  schedule_season           ...
# 6   1972       schedule_date  schedule_season           ...
# 7   1973       schedule_date  schedule_season           ...
# 8   1974       schedule_date  schedule_season           ...
# 9   1975       schedule_date  schedule_season           ...
# 10  1976       schedule_date  schedule_season           ...
# 11  1977       schedule_date  schedule_season           ...
# 12  1978       schedule_date  schedule_season           ...
# 13  1979       schedule_date  schedule_season           ...
# 14  1980       schedule_date  schedule_season           ...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d23fc35ec9ea> in <module>
#       2 c = 91.1
#       3 cd = [d,c]
# ----> 4 mean(cd)
#
# NameError: name 'mean' is not defined
